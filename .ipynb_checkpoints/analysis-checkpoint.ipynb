# %% [markdown]
# # Analysis of Historical S&P prices

# %% [markdown]
# ### Dec 29, 1927 - Present
# #### https://www.wsj.com/market-data/quotes/index/SPX/historical-prices

# %% [markdown]
# #### Windows commands for working dashboard
# python -m venv path\to\myenv
#
# cd path\to\myenv
#
# Scripts\activate.bat

# %% [markdown]
# ##### Dashboard setup

# %%
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ##### Reading Data

# %%
import pandas as pd

df_uncleaned = pd.read_csv('HistoricalPrices.csv')
df_uncleaned.head()
# Out:
#        Date     Open     High      Low    Close
# 0  11/30/22  3957.64  4080.11  3938.58  4080.11
# 1  11/29/22  3964.19  3976.77  3937.65  3957.63
# 2  11/28/22  4005.36  4012.27  3955.77  3963.94
# 3  11/25/22  4023.34  4034.02  4020.76  4026.12
# 4  11/23/22  4001.02  4033.78  3998.66  4027.26

# %% [markdown]
# #### Cleaning Data

# %%
import datetime

df = pd.DataFrame({"Month": [], "Day": [], "Year": [], "Day_Of_Week": [], "Avg_Daily_Cost": []})
df_uncleaned.columns = df_uncleaned.columns.str.replace(' ', '') # Clean bad col names
for i in range(len(df_uncleaned)):
    dt = df_uncleaned["Date"][i]
    month, day, year = (int(x) for x in dt.split('/'))
    if year < 50 and year >= 10:
        year = int("20" + str(year))
    elif year < 10 and year > 0:
        year = int("200" + str(year))
    elif year < 100 and year > 50:
        year = int("19" + str(year))
    else:
        year = 2000
    df.loc[i, "Month"] = month
    df.loc[i, "Day"] = day
    df.loc[i, "Year"] = year
    df.loc[i, "Day_Of_Week"] = int(datetime.datetime(year, month, day).weekday())
    df.loc[i, "Avg_Daily_Cost"] = (df_uncleaned.loc[i, "High"] + df_uncleaned.loc[i, "Low"]) / 2
df["Month"] = df["Month"].astype(int)
df["Day"] = df["Day"].astype(int)
df["Year"] = df["Year"].astype(int)
df["Day_Of_Week"] = df["Day_Of_Week"].astype(int)
df = pd.concat([df, df_uncleaned.iloc[:, 1:5]], axis = 1)
df.head()
# Out:
#    Month  Day  Year  Day_Of_Week  Avg_Daily_Cost     Open     High      Low  \
# 0     11   30  2022            2        4009.345  3957.64  4080.11  3938.58
# 1     11   29  2022            1        3957.210  3964.19  3976.77  3937.65
# 2     11   28  2022            0        3984.020  4005.36  4012.27  3955.77
# 3     11   25  2022            4        4027.390  4023.34  4034.02  4020.76
# 4     11   23  2022            2        4016.220  4001.02  4033.78  3998.66
#
#      Close
# 0  4080.11
# 1  3957.63
# 2  3963.94
# 3  4026.12
# 4  4027.26

# %% [markdown]
# ##### Interactive implementation

# %%
idf = df.interactive() # for interactive dashboard

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start = min(df.Year), end = max(df.Year), step = 1, value = min(df.Year))
#year_slider
yaxis_options = pn.widgets.CheckButtonGroup(
    name = "Y axis",
    options=["Open", "Avg_Daily_Cost", "Close"],
    button_type = 'success'
)
#yaxis_options
pipeline = (
    idf[
        (idf.Year <= year_slider)
    ]
    .groupby(['Year'])[yaxis_options].mean()
    .reset_index()
    .sort_values(by='Year')  
    .reset_index(drop=True)
)
#pipeline
source_bar_plot = pipeline.hvplot(kind='bar', 
                                  x='Year', 
                                  y=yaxis_options, 
                                  title='Trend by Year')
#source_bar_plot

# %%
df.to_csv('SaPPrices.csv')

# %% [markdown]
# ##### EDA

# %%
import numpy as np
import matplotlib.pyplot as plt

label = 'Day_Of_Week'
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
fig = plt.figure(figsize = (10, 8))
width = 0.25
changey = 1100
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3), ("Open", "Day Avg", "Close"))
plt.show()

# %%
label = 'Month'
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
fig = plt.figure(figsize = (10, 8))
width = 0.25
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3), ("Open", "Day Avg", "Close"))
plt.show()

# %%
label = 'Day'
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
fig = plt.figure(figsize = (10, 8))
width = 0.25
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3), ("Open", "Day Avg", "Close"))
plt.show()

# %%
label = 'Year'
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
fig = plt.figure(figsize = (10, 8))
width = 0.25
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3), ("Open", "Day Avg", "Close"))
plt.show()

# %% [markdown]
# ##### https://en.wikipedia.org/wiki/List_of_recessions_in_the_United_States

# %%
df.head()
df["Recession"] = False
# Out:
#    Month  Day  Year  Day_Of_Week  Avg_Daily_Cost     Open     High      Low  \
# 0     11   30  2022            2        4009.345  3957.64  4080.11  3938.58
# 1     11   29  2022            1        3957.210  3964.19  3976.77  3937.65
# 2     11   28  2022            0        3984.020  4005.36  4012.27  3955.77
# 3     11   25  2022            4        4027.390  4023.34  4034.02  4020.76
# 4     11   23  2022            2        4016.220  4001.02  4033.78  3998.66
#
#      Close  Recession
# 0  4080.11      False
# 1  3957.63      False
# 2  3963.94      False
# 3  4026.12      False
# 4  4027.26      False

# %%
df.loc[(df["Month"] >= 1) & (df["Month"] <= 7) & (df["Year"] == 1980), "Recession"] = True  # 1980 recession
df.loc[(df["Month"] >= 7) & (df["Month"] <= 12) & (df["Year"] == 1981), "Recession"] = True # 1981–1982 recession
df.loc[(df["Month"] >= 1) & (df["Month"] <= 11) & (df["Year"] == 1982), "Recession"] = True # 1981–1982 recession
df.loc[(df["Month"] >= 7) & (df["Month"] <= 12) & (df["Year"] == 1990), "Recession"] = True # Early 1990s recession
df.loc[(df["Month"] >= 1) & (df["Month"] <= 3) & (df["Year"] == 1991), "Recession"] = True  # Early 1990s recession
df.loc[(df["Month"] >= 3) & (df["Month"] <= 11) & (df["Year"] == 2001), "Recession"] = True  # Early 2000s recession
df.loc[(df["Month"] >= 12) & (df["Month"] <= 12) & (df["Year"] == 2007), "Recession"] = True  # Great Recession
df.loc[(df["Year"] == 2008), "Recession"] = True  # Great Recession
df.loc[(df["Month"] >= 1) & (df["Month"] <= 6) & (df["Year"] == 2009), "Recession"] = True  # Great Recession
df.loc[(df["Month"] >= 2) & (df["Month"] <= 4) & (df["Year"] == 2020), "Recession"] = True  # COVID-19 recession
print("Days in recession", sum(df["Recession"]), "/", len(df), "=", round(sum(df["Recession"]) / len(df) * 100), "%")
# Out:
# Days in recession 1342 / 11326 = 12 %

# %%
df2 = df.loc[df["Recession"] == True]
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
d = df2.groupby([label]).mean()["Avg_Daily_Cost"]
fig = plt.figure(figsize = (16, 8))
width = 0.2
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')
bar4 = plt.bar(d.keys() + width * 3, d - changey, width, color = 'r')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3, bar4), ("Open", "Day Avg", "Close", "Recession"))
plt.show()

# %%
df2 = df.loc[df["Recession"] == True]
label = "Day_Of_Week"
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
d = df2.groupby([label]).mean()["Avg_Daily_Cost"]
fig = plt.figure(figsize = (16, 8))
width = 0.2
changey = 600
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')
bar4 = plt.bar(d.keys() + width * 3, d - changey, width, color = 'r')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3, bar4), ("Open", "Day Avg", "Close", "Recession"))
plt.show()

# %%
df2 = df.loc[df["Recession"] == True]
label = "Day"
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
d = df2.groupby([label]).mean()["Avg_Daily_Cost"]
fig = plt.figure(figsize = (16, 8))
width = 0.2
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')
bar4 = plt.bar(d.keys() + width * 3, d - changey, width, color = 'r')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3, bar4), ("Open", "Day Avg", "Close", "Recession"))
plt.show()

# %%
df2 = df.loc[df["Recession"] == True]
label = "Month"
a = df.groupby([label]).mean()["Open"]
b = df.groupby([label]).mean()["Avg_Daily_Cost"]
c = df.groupby([label]).mean()["Close"]
d = df2.groupby([label]).mean()["Avg_Daily_Cost"]
fig = plt.figure(figsize = (16, 8))
width = 0.2
changey = 0
bar1 = plt.bar(a.keys(), a - changey, width, color = '#40798C')
bar2 = plt.bar(b.keys() + width, b - changey, width, color = '#F5CB5C')
bar3 = plt.bar(c.keys() + width * 2, c - changey, width, color = '#333533')
bar4 = plt.bar(d.keys() + width * 3, d - changey, width, color = 'r')

plt.xlabel(label)
plt.ylabel("Price" + " - " + str(changey))
plt.title("Difference in Price by " + label)
plt.legend((bar1, bar2, bar3, bar4), ("Open", "Day Avg", "Close", "Recession"))
plt.show()

# %%
daysRecessionByMonth = df.loc[df["Recession"] == True].groupby(["Month"]).sum()["Recession"] # sum of days in recession by month

label = "Month"
a = df.loc[df["Recession"] == True].groupby(["Month"]).sum()["Recession"]
fig = plt.figure(figsize = (16, 8))
width = 0.40
changey = 0
bar4 = plt.bar(a.keys() + width, a - changey, width)

plt.xlabel(label)
plt.ylabel("Amount of days")
plt.title("Days in recession by month")
plt.show()

# %% [markdown]
# Null hypothesis: Groups means are equal (no variation in means of groups)
#
# Alternative hypothesis: At least, one group mean is different from other groups
#
# ##### H0: μ1=μ2=…=μp
# ##### H1: All μ are not equal

# %%
import scipy.stats as stats

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18908\1294086001.py in <module>
# ----> 1 count(df)
#
# NameError: name 'count' is not defined
